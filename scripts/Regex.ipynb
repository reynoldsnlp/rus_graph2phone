# %%
import re
import pandas as pd

# %%
df = pd.read_csv('words.csv')
df.drop(0)
print(df)
# Out:
#          Level 0        Level 1  Level 2  Level 3  Level 4  Level 5  Level 6  \
# 0        иска́ть        иска́т'      NaN      NaN      NaN      NaN      NaN
# 1         тю́бик       т'у́б'ик      NaN      NaN      NaN      NaN      NaN
# 2          ма́ть          ма́т'      NaN      NaN      NaN      NaN      NaN
# 3        твёрдый      тв'о́рдый      NaN      NaN      NaN      NaN      NaN
# 4          име́л         им'э́л      NaN      NaN      NaN      NaN      NaN
# 5           се́л          с'э́л      NaN      NaN      NaN      NaN      NaN
# 6          но́ги         но́г'и      NaN      NaN      NaN      NaN      NaN
# 7         пи́шут        п'и́шут      NaN      NaN      NaN      NaN      NaN
# 8          пя́ть         п'а́т'      NaN      NaN      NaN      NaN      NaN
# 9          ся́ду         с'а́ду      NaN      NaN      NaN      NaN      NaN
# 10       ступлю́       ступл'у́      NaN      NaN      NaN      NaN      NaN
# 11       сту́пит       сту́п'ит      NaN      NaN      NaN      NaN      NaN
# 12          ле́т          л'э́т      NaN      NaN      NaN      NaN      NaN
# 13         зима́         з'има́      NaN      NaN      NaN      NaN      NaN
# 14         изю́м         из'у́м      NaN      NaN      NaN      NaN      NaN
# 15         я́рус         йа́рус      NaN      NaN      NaN      NaN      NaN
# 16         све́т         св'э́т      NaN      NaN      NaN      NaN      NaN
# 17         ю́ный         йу́ный      NaN      NaN      NaN      NaN      NaN
# 18      бле́дный      бл'э́дный      NaN      NaN      NaN      NaN      NaN
# 19     включа́ть     вкл'уча́т'      NaN      NaN      NaN      NaN      NaN
# 20          где́          гд'э́      NaN      NaN      NaN      NaN      NaN
# 21      гря́зный      гр'а́зный      NaN      NaN      NaN      NaN      NaN
# 22    сле́дующий   сл'э́дуйущий      NaN      NaN      NaN      NaN      NaN
# 23         чле́н         чл'э́н      NaN      NaN      NaN      NaN      NaN
# 24       жу́ткий       жу́тк'ий      NaN      NaN      NaN      NaN      NaN
# 25    извиня́юсь  изв'ин'а́йус'      NaN      NaN      NaN      NaN      NaN
# 26          клён         кл'о́н      NaN      NaN      NaN      NaN      NaN
# 27     чуде́сный     чуд'э́сный      NaN      NaN      NaN      NaN      NaN
# 28          мо́ю          мо́йу      NaN      NaN      NaN      NaN      NaN
# 29         я́щик         йа́щик      NaN      NaN      NaN      NaN      NaN
# ..           ...            ...      ...      ...      ...      ...      ...
# 182       нове́е       нов'э́йэ      NaN      NaN      NaN      NaN      NaN
# 183      чита́ет       чита́йэт      NaN      NaN      NaN      NaN      NaN
# 184        пло́д          пло́д      NaN      NaN      NaN      NaN      NaN
# 185        гла́з          гла́з      NaN      NaN      NaN      NaN      NaN
# 186         зу́б           зу́б      NaN      NaN      NaN      NaN      NaN
# 187         но́ж           но́ж      NaN      NaN      NaN      NaN      NaN
# 188        дру́г          дру́г      NaN      NaN      NaN      NaN      NaN
# 189      сто́рож        сто́рож      NaN      NaN      NaN      NaN      NaN
# 190      отре́жь       отр'э́ж'      NaN      NaN      NaN      NaN      NaN
# 191        ся́дь         с'а́д'      NaN      NaN      NaN      NaN      NaN
# 192         до́м           до́м      NaN      NaN      NaN      NaN      NaN
# 193        ста́р          ста́р      NaN      NaN      NaN      NaN      NaN
# 194      тру́бка        тру́бка      NaN      NaN      NaN      NaN      NaN
# 195       ло́дка         ло́дка      NaN      NaN      NaN      NaN      NaN
# 196        вку́с          вку́с      NaN      NaN      NaN      NaN      NaN
# 197     коро́бка       коро́бка      NaN      NaN      NaN      NaN      NaN
# 198     про́сьба       про́с'ба      NaN      NaN      NaN      NaN      NaN
# 199      вокза́л        вокза́л      NaN      NaN      NaN      NaN      NaN
# 200  занима́ться  зан'има́т'с'а      NaN      NaN      NaN      NaN      NaN
# 201      ска́зка        ска́зка      NaN      NaN      NaN      NaN      NaN
# 202      второ́й        второ́й      NaN      NaN      NaN      NaN      NaN
# 203      сгоре́л       сгор'э́л      NaN      NaN      NaN      NaN      NaN
# 204         и́зб           и́зб      NaN      NaN      NaN      NaN      NaN
# 205        ви́зг         в'и́зг      NaN      NaN      NaN      NaN      NaN
# 206       до́ждь         до́жд'      NaN      NaN      NaN      NaN      NaN
# 207       по́езд        по́йэзд      NaN      NaN      NaN      NaN      NaN
# 208      боро́зд        боро́зд      NaN      NaN      NaN      NaN      NaN
# 209       слу́жб         слу́жб      NaN      NaN      NaN      NaN      NaN
# 210      наде́жд       над'э́жд      NaN      NaN      NaN      NaN      NaN
# 211         да́р           да́р      NaN      NaN      NaN      NaN      NaN
#
#      Level 7  Level 8  Level 9  Level 10
# 0        NaN      NaN      NaN       NaN
# 1        NaN      NaN      NaN       NaN
# 2        NaN      NaN      NaN       NaN
# 3        NaN      NaN      NaN       NaN
# 4        NaN      NaN      NaN       NaN
# 5        NaN      NaN      NaN       NaN
# 6        NaN      NaN      NaN       NaN
# 7        NaN      NaN      NaN       NaN
# 8        NaN      NaN      NaN       NaN
# 9        NaN      NaN      NaN       NaN
# 10       NaN      NaN      NaN       NaN
# 11       NaN      NaN      NaN       NaN
# 12       NaN      NaN      NaN       NaN
# 13       NaN      NaN      NaN       NaN
# 14       NaN      NaN      NaN       NaN
# 15       NaN      NaN      NaN       NaN
# 16       NaN      NaN      NaN       NaN
# 17       NaN      NaN      NaN       NaN
# 18       NaN      NaN      NaN       NaN
# 19       NaN      NaN      NaN       NaN
# 20       NaN      NaN      NaN       NaN
# 21       NaN      NaN      NaN       NaN
# 22       NaN      NaN      NaN       NaN
# 23       NaN      NaN      NaN       NaN
# 24       NaN      NaN      NaN       NaN
# 25       NaN      NaN      NaN       NaN
# 26       NaN      NaN      NaN       NaN
# 27       NaN      NaN      NaN       NaN
# 28       NaN      NaN      NaN       NaN
# 29       NaN      NaN      NaN       NaN
# ..       ...      ...      ...       ...
# 182      NaN      NaN      NaN       NaN
# 183      NaN      NaN      NaN       NaN
# 184      NaN      NaN      NaN       NaN
# 185      NaN      NaN      NaN       NaN
# 186      NaN      NaN      NaN       NaN
# 187      NaN      NaN      NaN       NaN
# 188      NaN      NaN      NaN       NaN
# 189      NaN      NaN      NaN       NaN
# 190      NaN      NaN      NaN       NaN
# 191      NaN      NaN      NaN       NaN
# 192      NaN      NaN      NaN       NaN
# 193      NaN      NaN      NaN       NaN
# 194      NaN      NaN      NaN       NaN
# 195      NaN      NaN      NaN       NaN
# 196      NaN      NaN      NaN       NaN
# 197      NaN      NaN      NaN       NaN
# 198      NaN      NaN      NaN       NaN
# 199      NaN      NaN      NaN       NaN
# 200      NaN      NaN      NaN       NaN
# 201      NaN      NaN      NaN       NaN
# 202      NaN      NaN      NaN       NaN
# 203      NaN      NaN      NaN       NaN
# 204      NaN      NaN      NaN       NaN
# 205      NaN      NaN      NaN       NaN
# 206      NaN      NaN      NaN       NaN
# 207      NaN      NaN      NaN       NaN
# 208      NaN      NaN      NaN       NaN
# 209      NaN      NaN      NaN       NaN
# 210      NaN      NaN      NaN       NaN
# 211      NaN      NaN      NaN       NaN
#
# [212 rows x 11 columns]

# %%
vowels = 'аоэуияёеюы'
accented_vowels = 'а́о́э́у́и́я́ёе́ю́ы́'
vow_ak = 'ао'
consonants = ''

# %%
def softness(word):
    word = re.sub(r'\bю','йу',word)
    word = re.sub(r'\bя','йа',word)
    word = re.sub(r'\bе','йэ',word)
    word = re.sub(r'\bё','йо́',word)
    
    word = re.sub(r'(?<=[' + vowels + accented_vowels + 'ьъ])ю','йу',word)
    word = re.sub(r'(?<=[' + vowels + accented_vowels + 'ьъ])е','йэ',word)
    word = re.sub(r'(?<=[' + vowels + accented_vowels + 'ьъ])я','йа',word)
    word = re.sub(r'(?<=[' + vowels + accented_vowels + 'ьъ])ё','йо́',word)
    word = re.sub(r'(?<=[ьъ])и','йи',word)

    word = re.sub(r'(?<=[^йчщ])ь','\'',word)
    word = re.sub(r'(?<=[йчщ])ь','',word)
    word = re.sub(r'ъ','',word)
    word = re.sub(r'(?<=[^йчщ])ю','\'у',word)
    word = re.sub(r'(?<=[^йчщ])я','\'а',word)
    word = re.sub(r'(?<=[^йчщ])е','\'э',word)
    word = re.sub(r'(?<=[^йчщ])ё','\'о́',word)
    word = re.sub(r'(?<=[йчщ])ё','о́',word)
    word = re.sub(r'(?<=[йчщ])ю','у',word)
    word = re.sub(r'(?<=[йчщ])я','а',word)
    word = re.sub(r'(?<=[йчщ])е','э',word)
    word = re.sub(r'(?<=[^йчщжшц'+vowels+accented_vowels+'])и','\'и', word)

    return word

# %%
newColumn = []
for index, row in df.iterrows():
    newColumn.append(softness(row[0]))

# %%
df['Level 1'] = newColumn
df
# Out:
#          Level 0        Level 1  Level 2  Level 3  Level 4  Level 5  Level 6  \
# 0        иска́ть        иска́т'      NaN      NaN      NaN      NaN      NaN
# 1         тю́бик       т'у́б'ик      NaN      NaN      NaN      NaN      NaN
# 2          ма́ть          ма́т'      NaN      NaN      NaN      NaN      NaN
# 3        твёрдый      тв'о́рдый      NaN      NaN      NaN      NaN      NaN
# 4          име́л         им'э́л      NaN      NaN      NaN      NaN      NaN
# 5           се́л          с'э́л      NaN      NaN      NaN      NaN      NaN
# 6          но́ги         но́г'и      NaN      NaN      NaN      NaN      NaN
# 7         пи́шут        п'и́шут      NaN      NaN      NaN      NaN      NaN
# 8          пя́ть         п'а́т'      NaN      NaN      NaN      NaN      NaN
# 9          ся́ду         с'а́ду      NaN      NaN      NaN      NaN      NaN
# 10       ступлю́       ступл'у́      NaN      NaN      NaN      NaN      NaN
# 11       сту́пит       сту́п'ит      NaN      NaN      NaN      NaN      NaN
# 12          ле́т          л'э́т      NaN      NaN      NaN      NaN      NaN
# 13         зима́         з'има́      NaN      NaN      NaN      NaN      NaN
# 14         изю́м         из'у́м      NaN      NaN      NaN      NaN      NaN
# 15         я́рус         йа́рус      NaN      NaN      NaN      NaN      NaN
# 16         све́т         св'э́т      NaN      NaN      NaN      NaN      NaN
# 17         ю́ный         йу́ный      NaN      NaN      NaN      NaN      NaN
# 18      бле́дный      бл'э́дный      NaN      NaN      NaN      NaN      NaN
# 19     включа́ть     вкл'уча́т'      NaN      NaN      NaN      NaN      NaN
# 20          где́          гд'э́      NaN      NaN      NaN      NaN      NaN
# 21      гря́зный      гр'а́зный      NaN      NaN      NaN      NaN      NaN
# 22    сле́дующий   сл'э́дуйущий      NaN      NaN      NaN      NaN      NaN
# 23         чле́н         чл'э́н      NaN      NaN      NaN      NaN      NaN
# 24       жу́ткий       жу́тк'ий      NaN      NaN      NaN      NaN      NaN
# 25    извиня́юсь  изв'ин'а́йус'      NaN      NaN      NaN      NaN      NaN
# 26          клён         кл'о́н      NaN      NaN      NaN      NaN      NaN
# 27     чуде́сный     чуд'э́сный      NaN      NaN      NaN      NaN      NaN
# 28          мо́ю          мо́йу      NaN      NaN      NaN      NaN      NaN
# 29         я́щик         йа́щик      NaN      NaN      NaN      NaN      NaN
# ..           ...            ...      ...      ...      ...      ...      ...
# 182       нове́е       нов'э́йэ      NaN      NaN      NaN      NaN      NaN
# 183      чита́ет       чита́йэт      NaN      NaN      NaN      NaN      NaN
# 184        пло́д          пло́д      NaN      NaN      NaN      NaN      NaN
# 185        гла́з          гла́з      NaN      NaN      NaN      NaN      NaN
# 186         зу́б           зу́б      NaN      NaN      NaN      NaN      NaN
# 187         но́ж           но́ж      NaN      NaN      NaN      NaN      NaN
# 188        дру́г          дру́г      NaN      NaN      NaN      NaN      NaN
# 189      сто́рож        сто́рож      NaN      NaN      NaN      NaN      NaN
# 190      отре́жь       отр'э́ж'      NaN      NaN      NaN      NaN      NaN
# 191        ся́дь         с'а́д'      NaN      NaN      NaN      NaN      NaN
# 192         до́м           до́м      NaN      NaN      NaN      NaN      NaN
# 193        ста́р          ста́р      NaN      NaN      NaN      NaN      NaN
# 194      тру́бка        тру́бка      NaN      NaN      NaN      NaN      NaN
# 195       ло́дка         ло́дка      NaN      NaN      NaN      NaN      NaN
# 196        вку́с          вку́с      NaN      NaN      NaN      NaN      NaN
# 197     коро́бка       коро́бка      NaN      NaN      NaN      NaN      NaN
# 198     про́сьба       про́с'ба      NaN      NaN      NaN      NaN      NaN
# 199      вокза́л        вокза́л      NaN      NaN      NaN      NaN      NaN
# 200  занима́ться  зан'има́т'с'а      NaN      NaN      NaN      NaN      NaN
# 201      ска́зка        ска́зка      NaN      NaN      NaN      NaN      NaN
# 202      второ́й        второ́й      NaN      NaN      NaN      NaN      NaN
# 203      сгоре́л       сгор'э́л      NaN      NaN      NaN      NaN      NaN
# 204         и́зб           и́зб      NaN      NaN      NaN      NaN      NaN
# 205        ви́зг         в'и́зг      NaN      NaN      NaN      NaN      NaN
# 206       до́ждь         до́жд'      NaN      NaN      NaN      NaN      NaN
# 207       по́езд        по́йэзд      NaN      NaN      NaN      NaN      NaN
# 208      боро́зд        боро́зд      NaN      NaN      NaN      NaN      NaN
# 209       слу́жб         слу́жб      NaN      NaN      NaN      NaN      NaN
# 210      наде́жд       над'э́жд      NaN      NaN      NaN      NaN      NaN
# 211         да́р           да́р      NaN      NaN      NaN      NaN      NaN
#
#      Level 7  Level 8  Level 9  Level 10
# 0        NaN      NaN      NaN       NaN
# 1        NaN      NaN      NaN       NaN
# 2        NaN      NaN      NaN       NaN
# 3        NaN      NaN      NaN       NaN
# 4        NaN      NaN      NaN       NaN
# 5        NaN      NaN      NaN       NaN
# 6        NaN      NaN      NaN       NaN
# 7        NaN      NaN      NaN       NaN
# 8        NaN      NaN      NaN       NaN
# 9        NaN      NaN      NaN       NaN
# 10       NaN      NaN      NaN       NaN
# 11       NaN      NaN      NaN       NaN
# 12       NaN      NaN      NaN       NaN
# 13       NaN      NaN      NaN       NaN
# 14       NaN      NaN      NaN       NaN
# 15       NaN      NaN      NaN       NaN
# 16       NaN      NaN      NaN       NaN
# 17       NaN      NaN      NaN       NaN
# 18       NaN      NaN      NaN       NaN
# 19       NaN      NaN      NaN       NaN
# 20       NaN      NaN      NaN       NaN
# 21       NaN      NaN      NaN       NaN
# 22       NaN      NaN      NaN       NaN
# 23       NaN      NaN      NaN       NaN
# 24       NaN      NaN      NaN       NaN
# 25       NaN      NaN      NaN       NaN
# 26       NaN      NaN      NaN       NaN
# 27       NaN      NaN      NaN       NaN
# 28       NaN      NaN      NaN       NaN
# 29       NaN      NaN      NaN       NaN
# ..       ...      ...      ...       ...
# 182      NaN      NaN      NaN       NaN
# 183      NaN      NaN      NaN       NaN
# 184      NaN      NaN      NaN       NaN
# 185      NaN      NaN      NaN       NaN
# 186      NaN      NaN      NaN       NaN
# 187      NaN      NaN      NaN       NaN
# 188      NaN      NaN      NaN       NaN
# 189      NaN      NaN      NaN       NaN
# 190      NaN      NaN      NaN       NaN
# 191      NaN      NaN      NaN       NaN
# 192      NaN      NaN      NaN       NaN
# 193      NaN      NaN      NaN       NaN
# 194      NaN      NaN      NaN       NaN
# 195      NaN      NaN      NaN       NaN
# 196      NaN      NaN      NaN       NaN
# 197      NaN      NaN      NaN       NaN
# 198      NaN      NaN      NaN       NaN
# 199      NaN      NaN      NaN       NaN
# 200      NaN      NaN      NaN       NaN
# 201      NaN      NaN      NaN       NaN
# 202      NaN      NaN      NaN       NaN
# 203      NaN      NaN      NaN       NaN
# 204      NaN      NaN      NaN       NaN
# 205      NaN      NaN      NaN       NaN
# 206      NaN      NaN      NaN       NaN
# 207      NaN      NaN      NaN       NaN
# 208      NaN      NaN      NaN       NaN
# 209      NaN      NaN      NaN       NaN
# 210      NaN      NaN      NaN       NaN
# 211      NaN      NaN      NaN       NaN
#
# [212 rows x 11 columns]

# %%
df.to_csv('words.csv', index=False)
